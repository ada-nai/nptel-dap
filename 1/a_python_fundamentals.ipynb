# %% [markdown]
# <a href="https://colab.research.google.com/github/ada-nai/nptel-dap/blob/master/1/a_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading a simple delimited file

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ada-nai/nptel-dap/master/1/data/gapminder.csv')

# %%
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# # Printing rows of DF

# %% [markdown]
# ## Print first 5 rows

# %%
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# ## Print last 5 rows

# %%
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %% [markdown]
# # Print shape of the dataframe

# %%
df.shape
# Out:
# (1704, 6)

# %% [markdown]
# # Obtain column names of DF

# %%
df.columns.to_list()
# Out:
# ['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap']

# %% [markdown]
# # Get datatype of each column

# %%
df.dtypes
# Out:
# country       object
# year           int64
# pop          float64
# continent     object
# lifeExp      float64
# gdpPercap    float64
# dtype: object

# %% [markdown]
# # Get basic information of each columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# # Accessing specific columns

# %% [markdown]
# ## Accessing a column

# %%
country_df = df['country']

# %%
country_df.head()

# %% [markdown]
# ## Accessing a subset of columns

# %%
subset = df[['country', 'continent', 'year']]
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
# First 5 rows
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
# Last 5 rows
subset.tail()
# Out:
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007

# %% [markdown]
# # Indexing in DFs

# %% [markdown]
# ## `loc`

# %%
# Access first row (zero-indexing)
df.loc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
# Access 100th row 
df.loc[99]
# Out:
# country      Bangladesh
# year               1967
# pop          62821884.0
# continent          Asia
# lifeExp          43.453
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
# Select 1st, 100th, 1000th row
df.loc[[0, 99, 999]]
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %% [markdown]
# ## `iloc`
# Indexed location

# %%
# Access second record
df.iloc[1]
# Out:
# country      Afghanistan
# year                1957
# pop            9240934.0
# continent           Asia
# lifeExp           30.332
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
# Negative indexing (last record)
df.iloc[-1]
# Out:
# country        Zimbabwe
# year               2007
# pop          12311143.0
# continent        Africa
# lifeExp          43.487
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %% [markdown]
# # Subsetting columns

# %% [markdown]
# ## Subset using `loc`

# %%
# Obtain all records for only two columns ['year', 'pop']
subset = df.loc[:, ['year', 'pop']]
subset.head()
# Out:
#    year         pop
# 0  1952   8425333.0
# 1  1957   9240934.0
# 2  1962  10267083.0
# 3  1967  11537966.0
# 4  1972  13079460.0

# %% [markdown]
# ## Subset using `iloc`

# %%
subset = df.iloc[:, [2, 4, -1]]
subset.head()
# Out:
#           pop  lifeExp   gdpPercap
# 0   8425333.0   28.801  779.445314
# 1   9240934.0   30.332  820.853030
# 2  10267083.0   31.997  853.100710
# 3  11537966.0   34.020  836.197138
# 4  13079460.0   36.088  739.981106

# %%
# Subset using range
small_range = range(6)
df.iloc[:5, small_range]
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %% [markdown]
# # Subsetting rows and columns

# %%
df.loc[42, 'country']
# Out:
# 'Angola'

# %%
# Get 1st, 100th, 1000th rows from 1st, 4th, 6th column
df.iloc[[0, 99, 999], [0, 3, 5]]
# Out:
#          country continent    gdpPercap
# 0    Afghanistan      Asia   779.445314
# 99    Bangladesh      Asia   721.186086
# 999     Mongolia      Asia  1226.041130

# %%
df.loc[[0, 99, 999], ['country', 'lifeExp', 'gdpPercap']]
# Out:
#          country  lifeExp    gdpPercap
# 0    Afghanistan   28.801   779.445314
# 99    Bangladesh   43.453   721.186086
# 999     Mongolia   51.253  1226.041130

# %% [markdown]
# # Aggregation using `groupby`

# %%
# Obtain mean average life expectancy per country
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
# multi groupby
multi = df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean()
multi.head(10)
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455

# %% [markdown]
# # Flatten DF

# %%
flat = multi.reset_index()
flat.head()
# Out:
#    year continent    lifeExp     gdpPercap
# 0  1952    Africa  39.135500   1252.572466
# 1  1952  Americas  53.279840   4079.062552
# 2  1952      Asia  46.314394   5195.484004
# 3  1952    Europe  64.408500   5661.057435
# 4  1952   Oceania  69.255000  10298.085650

# %% [markdown]
# # Get unique values

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# # Basic plot

# %%
yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
yearly_life_expectancy.head()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# Name: lifeExp, dtype: float64

# %%
plt.plot(yearly_life_expectancy)
plt.title('Year wise mean global life expectancy')
# Out:
# Text(0.5, 1.0, 'Year wise mean global life expectancy')
